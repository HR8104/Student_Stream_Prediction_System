# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# C:\Users\student\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
student_df = pd.read_csv("student_data.csv")
student_df.head()
# Out:
#    Student ID  Math Score  Science Score  English Score  Social Studies Score  \
# 0           1          82             63             98                   100
# 1           2          85             63             57                    66
# 2           3          91             75             91                    65
# 3           4          72             66             66                    78
# 4           5          58             69             73                    60
#
#    Interest  Logical Aptitude  Verbal Aptitude  Quantitative Aptitude  \
# 0  Commerce                77               87                     96
# 1      Arts                79               69                     81
# 2   Science                88               92                     82
# 3      Arts                91               83                     86
# 4  Commerce                75               75                     62
#
#   Career Interest Recommended Stream
# 0       Economist               Arts
# 1          Writer           Commerce
# 2          Doctor               Arts
# 3        Designer               Arts
# 4    Entrepreneur           Commerce

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student ID             3000 non-null   int64
#  1   Math Score             3000 non-null   int64
#  2   Science Score          3000 non-null   int64
#  3   English Score          3000 non-null   int64
#  4   Social Studies Score   3000 non-null   int64
#  5   Interest               3000 non-null   object
#  6   Logical Aptitude       3000 non-null   int64
#  7   Verbal Aptitude        3000 non-null   int64
#  8   Quantitative Aptitude  3000 non-null   int64
#  9   Career Interest        3000 non-null   object
#  10  Recommended Stream     3000 non-null   object
# dtypes: int64(8), object(3)
# memory usage: 257.9+ KB

# %%
 student_data = student_df.drop(["Interest","Student ID"],axis = 1)
student_data.head()
# Out:
#    Math Score  Science Score  English Score  Social Studies Score  \
# 0          82             63             98                   100
# 1          85             63             57                    66
# 2          91             75             91                    65
# 3          72             66             66                    78
# 4          58             69             73                    60
#
#    Logical Aptitude  Verbal Aptitude  Quantitative Aptitude Career Interest  \
# 0                77               87                     96       Economist
# 1                79               69                     81          Writer
# 2                88               92                     82          Doctor
# 3                91               83                     86        Designer
# 4                75               75                     62    Entrepreneur
#
#   Recommended Stream
# 0               Arts
# 1           Commerce
# 2               Arts
# 3               Arts
# 4           Commerce

# %%
    student_data.head(1000)
# Out:
#      Math Score  Science Score  English Score  Social Studies Score  \
# 0            82             63             98                   100
# 1            85             63             57                    66
# 2            91             75             91                    65
# 3            72             66             66                    78
# 4            58             69             73                    60
# ..          ...            ...            ...                   ...
# 995          58             61             53                    97
# 996          89             98             56                    61
# 997          78             73             79                    89
# 998          90             98             87                    68
# 999          80             73             50                    93
#
#      Logical Aptitude  Verbal Aptitude  Quantitative Aptitude Career Interest  \
# 0                  77               87                     96       Economist
# 1                  79               69                     81          Writer
# 2                  88               92                     82          Doctor
# 3                  91               83                     86        Designer
# 4                  75               75                     62    Entrepreneur
# ..                ...              ...                    ...             ...
# 995                94               77                    100    Entrepreneur
# 996                64               80                     64          Artist
# 997                62               88                     64       Scientist
# 998                84               94                     80       Scientist
# 999                69               82                     65          Artist
#
#     Recommended Stream
# 0                 Arts
# 1             Commerce
# 2                 Arts
# 3                 Arts
# 4             Commerce
# ..                 ...
# 995               Arts
# 996            Science
# 997               Arts
# 998            Science
# 999               Arts
#
# [1000 rows x 9 columns]

# %%
student_data['Stream'] = student_data['Recommended Stream'].map({'Arts': -1, 'Commerce': 0, 'Science': 1})
student_data.head()
# Out:
#    Math Score  Science Score  English Score  Social Studies Score  \
# 0          82             63             98                   100
# 1          85             63             57                    66
# 2          91             75             91                    65
# 3          72             66             66                    78
# 4          58             69             73                    60
#
#    Logical Aptitude  Verbal Aptitude  Quantitative Aptitude Career Interest  \
# 0                77               87                     96       Economist
# 1                79               69                     81          Writer
# 2                88               92                     82          Doctor
# 3                91               83                     86        Designer
# 4                75               75                     62    Entrepreneur
#
#   Recommended Stream  Stream
# 0               Arts      -1
# 1           Commerce       0
# 2               Arts      -1
# 3               Arts      -1
# 4           Commerce       0

# %%
df = student_data.drop(['Recommended Stream','Career Interest'],axis = 1)
df.head()
# Out:
#    Math Score  Science Score  English Score  Social Studies Score  \
# 0          82             63             98                   100
# 1          85             63             57                    66
# 2          91             75             91                    65
# 3          72             66             66                    78
# 4          58             69             73                    60
#
#    Logical Aptitude  Verbal Aptitude  Quantitative Aptitude  Stream
# 0                77               87                     96      -1
# 1                79               69                     81       0
# 2                88               92                     82      -1
# 3                91               83                     86      -1
# 4                75               75                     62       0

# %%
df.describe()
# Out:
#         Math Score  Science Score  English Score  Social Studies Score  \
# count  3000.000000    3000.000000    3000.000000           3000.000000
# mean     74.866000      75.525667      74.915667             74.874000
# std      14.681481      14.718635      14.655971             14.666987
# min      50.000000      50.000000      50.000000             50.000000
# 25%      62.000000      63.000000      62.000000             62.000000
# 50%      75.000000      76.000000      75.000000             75.000000
# 75%      88.000000      89.000000      88.000000             87.000000
# max     100.000000     100.000000     100.000000            100.000000
#
#        Logical Aptitude  Verbal Aptitude  Quantitative Aptitude       Stream
# count       3000.000000      3000.000000            3000.000000  3000.000000
# mean          79.935000        80.037000              80.434333    -0.401000
# std           11.963632        11.574957              11.925229     0.773131
# min           60.000000        60.000000              60.000000    -1.000000
# 25%           70.000000        70.000000              70.000000    -1.000000
# 50%           80.000000        80.000000              80.000000    -1.000000
# 75%           91.000000        90.000000              91.000000     0.000000
# max          100.000000       100.000000             100.000000     1.000000

# %%
x = df.drop(["Stream"],axis = 1)
y = df["Stream"]

# %%
from sklearn.model_selection import train_test_split

def classify(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    # train the model
    model.fit(x_train, y_train)
    print("Accuracy:", model.score(x_test, y_test) * 100)
    return model

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression model
model = LogisticRegression(max_iter=1000, solver='lbfgs')  # Adjust solver if needed

# Train and evaluate using the classify function
LinearReg_acc = classify(model, x, y)
print("Logistic Regression Accuracy:", LinearReg_acc)
# Out:
# Accuracy: 85.16666666666667
# Logistic Regression Accuracy: LogisticRegression(max_iter=1000)

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=1)
SVM_acc = classify(model, x, y)
print("SVM Accuracy:", SVM_acc)
# Out:
# Accuracy: 91.66666666666666
# SVM Accuracy: SVC(random_state=1)

# %%
Accuracy = [SVM_acc]
models = ['Support Vector Machine']

# %%
import joblib
from sklearn.svm import SVC
# Initialize the SVC model
model = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=1)

# Train and evaluate using the classify function
SVM_acc = classify(model, x, y)
print("SVM Accuracy:", SVM_acc)
joblib.dump(SVM_acc, 'svm_model1.pkl')
# Out:
# Accuracy: 91.66666666666666
# SVM Accuracy: SVC(random_state=1)
# ['svm_model.pkl']
